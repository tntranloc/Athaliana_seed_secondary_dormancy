# %%
import plotly

# %%
import statsmodels as statmod
import numpy as np
import scipy as sp
import patsy

# %%
import plotly.express as px

# %%
import os

# %%
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/nhutran/Documents/PhD/dormancy_redo/runs'

# %%
os.chdir('/Users/nhutran/Documents/PhD/Results_dormancy')

# %%
df = pd.read_csv('/Users/nhutran/Documents/PhD/dormancy_redo/runs/sem/dorm02_ft10_signifsnp_for_sem.csv')

# %%
#df1 = pd.read_csv('dorm.for.mapping.csv')

# %%
df1a = pd.read_csv('/Users/nhutran/Documents/PhD/dormancy_redo/assays/assay_pdorm02_working_bio.csv')

# %%
df1b = pd.read_csv('/Users/nhutran/Documents/PhD/dormancy_redo/assays/assay_sdorm02_working_bio.csv')

# %%
df1c = pd.read_csv('/Users/nhutran/Documents/PhD/dormancy_redo/assays/assay_control02_working_bio.csv')

# %%
df2 = pd.read_csv('/Users/nhutran/Documents/PhD/dormancy_redo/assays/assay_sdorm02_working_bio_setnotes.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0   ID Internal_id  germinated  total  non_germinated      rate  \
# 0         211   88   2021-0787          86     86               0  1.000000
# 1           8  108   2021-0788           0     64              64  0.000000
# 2          37  139   2021-0549           0     65              65  0.000000
# 3          39  159   2021-0790          17     48              31  0.354167
# 4          45  350   2021-0791          50     63              13  0.793651
#
#    Source_name       name                              Parents_id  ...  bio11  \
# 0  A. thaliana        CYR    88 (Almudena Molla Morales, Austria)  ...    4.3
# 1  A. thaliana     LDV-18  108  (Almudena Molla Morales, Austria)  ...    6.2
# 2  A. thaliana     LDV-46                                2017-049  ...    6.2
# 3  A. thaliana     MAR2-3  159  (Almudena Molla Morales, Austria)  ...    2.5
# 4  A. thaliana  TOU-A1-88   350 (Almudena Molla Morales, Austria)  ...    2.7
#
# ...

# %%
df1a['treatment'] = 'pdorm'
df1b['treatment'] = 'sdorm'
df1c['treatment'] = 'control'

# %%
merge = pd.concat([df1a,df1b,df1c])

# %%
#PLOT PDORM SDORM COLOURED BY BIO9, LATITUDE OR ORIGIN

# %%
fig_pdorm_sdorm = px.scatter(df, x='pdorm',y='sdorm',color = 'Latitude', hover_name = "Admixture_as_database", 
                  hover_data = ["bio9","Latitude","Longitude"],
                 trendline = 'ols', template = "simple_white",
                color_continuous_scale = 'deep',
                labels={"pdorm": "Primary dormancy (germination rate)",
                        "sdorm": "Secondary dormancy (germination rate)",
                       "bio9":"BIO9"}
                        )

# %%
df.head()
# Out:
#    ft10_5_3184569  ft10_5_3185003     ID Internal_id  sdorm_rate  pdorm_rate  \
# 0               0               0  10005   2021-0694    0.000000       0.923
# 1               0               0  10017   2021-0720    0.048780       1.000
# 2               1               1   1002   2021-0682    0.000000       0.946
# 3               0               0   1061   2021-0691    0.000000       0.900
# 4               0               0   1062   2021-0609    0.955556       1.000
#
#    Source_name              name Parents_id Admixture_internal  ... bio15  \
# 0  A. thaliana   ICE63 / Copac-1   2017-264     Central Europe  ...    30
# 1  A. thaliana   ICE21 / Petro-1   2017-263     Central Europe  ...    24
# 2  A. thaliana  Ale-Stenar-64-24   2017-351             Sweden  ...    21
# 3  A. thaliana    Brösarp-11-135   2017-352             Sweden  ...    21
# 4  A. thaliana    Brösarp-15-138   2017-153             Sweden  ...    21
#
# ...

# %%
df2 = df2.rename(columns = {'Admixture_as_database':'Origin'})
df2['Origin'] = df2['Origin'].map(
    {'central_europe':'Central Europe',
                    'western_europe':'Western Europe',
                    'spain':'Spain',
                    'south_sweden':'South Sweden',
                    'north_sweden':'North Sweden',
                    'germany':'Germany',                                             
                    'admixed':'Admixed'})

# %%
fig_ft10_ft16 = px.scatter(df, x='FT16',y='FT10',color = 'Origin', symbol = 'Origin',
                           hover_name = "name", 
                  hover_data = ["sdorm_rate","pdorm_rate","bio9"],
                 trendline = 'ols', trendline_scope = 'overall', template = "simple_white",
                color_discrete_sequence = px.colors.qualitative.Safe,
                labels={"FT10": "Flowering time at 10 Celcius degree",
                        "FT16": "Flowering time at 16 Celcius degree"}
                        )

# %%
fig_ft10_ft16.show()
# Out:
# <div>                            <div id="eb13fbc3-4357-4350-9b13-91b687ef4b7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb13fbc3-4357-4350-9b13-91b687ef4b7b")) {                    Plotly.newPlot(                        "eb13fbc3-4357-4350-9b13-91b687ef4b7b",                        [{"customdata":[[0.0,0.923,1.3],[0.048780488,1.0,2.5],[0.463414634,1.0,-0.6],[0.847826087,0.962,-2.3],[1.0,1.0,-0.7],[0.0,0.9,0.2],[0.851851852,0.717,-0.7],[0.977011494,0.842,-0.7],[0.966666667,1.0,-0.7],[0.760869565,1.0,-0.6],[0.0,0.884,-2.3],[0.93877551,0.865,-0.2],[0.672413793,0.96,3.2],[0.977272727,0.85,1.1],[0.45,1.0,0.8],[0.146341463,0.972,3.1],[0.454545455,1.0,1.6],[0.560606061,0.986,1.6],[0.345454545,0.95,1.4],[0.044444444,0.908,1.7],[1.0,0.968,1.6],[1.0,1
# ...

# %%
fig_ft10_ft16.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_ft10_ft16_dorm02.html')

# %%
fig_ft10_ft16_indiv = px.scatter(df, x='FT16',y='FT10',color = 'Origin', symbol = 'Origin',
                           hover_name = "name", 
                  hover_data = ["sdorm_rate","pdorm_rate","bio9"],
                 trendline = 'ols', template = "simple_white",
                color_discrete_sequence = px.colors.qualitative.Safe,
                labels={"FT10": "Flowering time at 10 Celcius degree",
                        "FT16": "Flowering time at 16 Celcius degree"}
                        )

# %%
fig_ft10_ft16_indiv.show()
# Out:
# <div>                            <div id="5a0c1fae-7625-4d0c-a22a-cc23c34c671e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a0c1fae-7625-4d0c-a22a-cc23c34c671e")) {                    Plotly.newPlot(                        "5a0c1fae-7625-4d0c-a22a-cc23c34c671e",                        [{"customdata":[[0.0,0.923,1.3],[0.048780488,1.0,2.5],[0.463414634,1.0,-0.6],[0.847826087,0.962,-2.3],[1.0,1.0,-0.7],[0.0,0.9,0.2],[0.851851852,0.717,-0.7],[0.977011494,0.842,-0.7],[0.966666667,1.0,-0.7],[0.760869565,1.0,-0.6],[0.0,0.884,-2.3],[0.93877551,0.865,-0.2],[0.672413793,0.96,3.2],[0.977272727,0.85,1.1],[0.45,1.0,0.8],[0.146341463,0.972,3.1],[0.454545455,1.0,1.6],[0.560606061,0.986,1.6],[0.345454545,0.95,1.4],[0.044444444,0.908,1.7],[1.0,0.968,1.6],[1.0,1
# ...

# %%
fig_ft10_ft16_indiv.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_ft10_ft16_dorm02_indiv.html')

# %%
fig6 = px.scatter(df1, x='pdorm',y='sdorm',color = 'Latitude', hover_name = "Origin", hover_data = ["bio9","Latitude"],
                 trendline = 'ols', template = "simple_white",
                color_continuous_scale = 'deep',
                labels={"pdorm": "Primary dormancy (germination rate)",
                        "sdorm": "Secondary dormancy (germination rate)",
                       "bio9":"BIO9"}
                 )

# %%
fig7 = px.scatter(df1, x='pdorm',y='sdorm',color = 'Origin', symbol = 'Origin',  
                 trendline = 'ols', trendline_scope = 'overall',template = "simple_white",
                color_discrete_sequence = px.colors.qualitative.Safe,
                labels={"pdorm": "Primary dormancy (germination rate)",
                        "sdorm": "Secondary dormancy (germination rate)",
                       "bio9":"BIO9"}
                        )

# %%
fig7.show()
# Out:
# <div>                            <div id="608c2e62-b282-4345-8ae5-0c51f8f27e0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("608c2e62-b282-4345-8ae5-0c51f8f27e0f")) {                    Plotly.newPlot(                        "608c2e62-b282-4345-8ae5-0c51f8f27e0f",                        [{"customdata":[[25.4,38.3333],[23.9,38.68],[22.3,39.66],[23.799999999999997,40.05],[20.6,40.29],[22.5,40.4],[21.6,40.44],[0.8999999999999999,40.45],[22.6,40.46],[16.9,40.46],[21.6,40.46],[22.5,40.48],[21.0,40.5],[21.0,40.5],[20.4,40.52],[20.4,40.59],[21.200000000000003,40.61],[20.4,40.65],[18.9,40.71],[21.1,40.71],[21.1,40.72],[19.9,40.89],[20.2,40.93],[20.2,40.94],[19.9,40.95],[20.1,41.0],[18.3,41.03],[3.9000000000000004,41.13],[17.8,41.14],[17.7,41.14],[18.7,41
# ...

# %%
fig5 = px.scatter(df2, x='Latitude',y='rate',symbol = 'Origin',color = 'Origin',
                 trendline = 'ols', trendline_scope = 'overall',
                  template = "simple_white",
                color_discrete_sequence = px.colors.qualitative.Safe,
                labels={"sdorm": "Secondary dormancy (germination rate)"}
                        )

# %%
##BOX PLOT

# %%
# 'merge' df is new experiment

# %%
merge = merge.rename(columns = {'Admixture_as_database':'Origin','treatment':'Group'})
merge['Origin'] = merge['Origin'].map(
    {'central_europe':'Central Europe',
                    'western_europe':'Western Europe',
                    'spain':'Spain',
                    'south_sweden':'South Sweden',
                    'north_sweden':'North Sweden',
                    'germany':'Germany',                                             
                    'admixed':'Admixed'}) 
merge['Group'] = merge['Group'].map(
    {'pdorm':'Primary dormancy','sdorm':'Secondary dormancy', 'control':'Control'})

# %%
merge = merge.rename(columns = {'rate':'Germination rate'})

# %%
merge_sdorm = merge[merge['Group'] == 'Secondary dormancy']

# %%
merge_sdorm = merge_sdorm.rename(columns = {'iso_alpha':'ISO-ALPHA'})

# %%
merge_sdorm = merge_sdorm.sort_values(by=['ISO-ALPHA'])

# %%
fig_box_psdorm = px.box(merge, y="Germination rate", x="Group",color ="Origin",
                       color_discrete_sequence = px.colors.qualitative.Safe)

# %%
fig_box_psdorm.show()
# Out:
# <div>                            <div id="f44b5202-0257-43aa-881f-f81ddff0a52e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f44b5202-0257-43aa-881f-f81ddff0a52e")) {                    Plotly.newPlot(                        "f44b5202-0257-43aa-881f-f81ddff0a52e",                        [{"alignmentgroup":"True","hovertemplate":"Origin=Central Europe<br>Group=%{x}<br>Germination rate=%{y}<extra></extra>","legendgroup":"Central Europe","marker":{"color":"rgb(136, 204, 238)"},"name":"Central Europe","notched":false,"offsetgroup":"Central Europe","orientation":"v","showlegend":true,"x":["Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dorm
# ...

# %%
fig_box_psdorm_old.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_NEW_psdorm_wcontrol.html')

# %%
#'df' is the old experiment

# %%
df = df.rename(columns = {'Admixture_as_database':'Origin','Treatment':'Group'})
df['Origin'] = df['Origin'].map(
    {'central_europe':'Central Europe',
                    'western_europe':'Western Europe',
                    'spain':'Spain',
                    'south_sweden':'South Sweden',
                    'north_sweden':'North Sweden',
                    'germany':'Germany',                                             
                    'admixed':'Admixed'}) 
df['Group'] = df['Group'].map(
    {'primary_dormancy':'Primary dormancy',
     'Secondary_dormancy':'Secondary dormancy', 
     '4degree':'Control'})

# %%
df = df.rename(columns = {'Germination_rate':'Germination rate'})

# %%
df = df.rename(columns = {'Iso.alpha':'ISO-ALPHA'})

# %%
pdorm = df[df['Group'] == 'primary_dormancy']
sdorm = df[df['Group'] == 'Secondary_dormancy']

# %%
oldps = pd.concat([pdorm, sdorm])

# %%
oldps = oldps.rename(columns = {'Germination_rate':'Germination rate'})

# %%
oldps = oldps.rename(columns = {'Iso.alpha':'ISO-ALPHA'})

# %%
oldps = oldps.sort_values(by=['ISO-ALPHA'])

# %%
fig_box_psdorm_old = px.box(oldps, y="Germination rate", x="Group",color ="Origin",
                       color_discrete_sequence = px.colors.qualitative.Safe)

# %%
fig_box_psdorm_old.show()
# Out:
# <div>                            <div id="8f10ae0e-e7f9-4574-ab62-ba6b0696ec60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f10ae0e-e7f9-4574-ab62-ba6b0696ec60")) {                    Plotly.newPlot(                        "8f10ae0e-e7f9-4574-ab62-ba6b0696ec60",                        [{"alignmentgroup":"True","hovertemplate":"Origin=Western Europe<br>Group=%{x}<br>Germination rate=%{y}<extra></extra>","legendgroup":"Western Europe","marker":{"color":"rgb(136, 204, 238)"},"name":"Western Europe","notched":false,"offsetgroup":"Western Europe","orientation":"v","showlegend":true,"x":["Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dormancy","Primary dorm
# ...

# %%
fig_box_psdorm_old.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_OLD_psdorm.html')

# %%
#'df2' is the new set but with "subset" column indicating which samples are
#included and not included in two experiments

# %%
df2 = df2.rename(columns = {'Admixture_as_database':'Origin'})

# %%
df2 = df2.rename(columns = {'iso_alpha':'ISO-ALPHA'})

# %%
df2['Origin'] = df2['Origin'].map({'central_europe':'Central Europe',
                    'western_europe':'Western Europe',
                    'spain':'Spain',
                    'south_sweden':'South Sweden',
                    'north_sweden':'North Sweden',
                    'germany':'Germany',                                             
                    'admixed':'Admixed'})

# %%
fig_sampling_map = px.scatter_mapbox(sdorm, lat="Latitude", lon="Longitude",
                  color_discrete_sequence = px.colors.qualitative.Vivid, zoom=3,
                         hover_name = "Genotype", 
                         hover_data = ["Latitude","Longitude","Origin","ISO-ALPHA"],
                        center={"lat": 54.5, "lon": 15.2},
                  mapbox_style="carto-positron")

# %%
fig_sampling_map = px.scatter_mapbox(df2, lat="Latitude", lon="Longitude",color = "subset"
                  color_discrete_sequence = px.colors.qualitative.Vivid, zoom=3,
                         hover_name = "Genotype", 
                         hover_data = ["Latitude","Longitude","Origin","ISO-ALPHA"],
                        center={"lat": 54.5, "lon": 15.2},
                  mapbox_style="carto-positron")

# %%
fig_sampling_map.show()
# Out:
# <div>                            <div id="25720343-f057-47e3-bff6-30b22c08f889" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25720343-f057-47e3-bff6-30b22c08f889")) {                    Plotly.newPlot(                        "25720343-f057-47e3-bff6-30b22c08f889",                        [{"customdata":[[48.5167,-4.06667,"Western Europe","FRA"],[49.4211,16.3497,"Central Europe","CZE"],[55.3833,14.05,"South Sweden","SWE"],[55.3833,14.05,"South Sweden","SWE"],[55.3833,14.05,"South Sweden","SWE"],[55.3833,14.05,"South Sweden","SWE"],[51.3,0.5,"Western Europe","UK"],[51.3,0.4,"Admixed","UK"],[54.5,-3.0,"Western Europe","UK"],[56.3333,15.9667,"South Sweden","SWE"],[56.3333,15.9667,"South Sweden","SWE"],[55.76,14.12,"South Sweden","SWE"],[55.76,14.12,"S
# ...

# %%
fig_sampling_map.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_OLD_sampling_map.html')

# %%
#DORMANCY AND LATITUDE MAP
fig_sdorm_lat = px.scatter(df2, x='Latitude',y='rate',symbol = 'Origin',
                  color = 'Origin',hover_name = "name",
                  hover_data = ["rate","Origin","iso_alpha","bio9","Longitude"],
                 trendline = 'ols', trendline_scope = 'overall',
                  template = "simple_white",
                color_discrete_sequence = px.colors.qualitative.Safe,
                labels={"rate": "Secondary dormancy (germination rate)"}
                        )

# %%
fig_sdorm_lat.update_layout(font=dict(size=14))
# Out:
# <div>                            <div id="e2f6ce3d-23c8-4bcf-9adf-e67c1d574c8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2f6ce3d-23c8-4bcf-9adf-e67c1d574c8d")) {                    Plotly.newPlot(                        "e2f6ce3d-23c8-4bcf-9adf-e67c1d574c8d",                        [{"customdata":[["Western Europe","FRA",18.5,0.68],["Western Europe","FRA",15.6,-4.07],["Western Europe","FRA",15.6,-4.07],["Western Europe","FRA",6.5,3.93],["Western Europe","FRA",6.7,4.12],["Western Europe","FRA",6.7,4.12],["Western Europe","UK",6.3,0.5],["Western Europe","UK",8.8,-3.0],["Western Europe","SWE",2.6,13.12],["Western Europe","FRA",19.1,1.3],["Western Europe","UK",6.4,-0.64],["Western Europe","UK",6.4,-0.64],["Western Europe","FRA",4.3,3.3],["Wester
# ...

# %%
fig_sdorm_lat.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_NEW_sdorm_lat.html')

# %%
#DO SOME CORRELATION TEST

# %%
import scipy.stats as stats

# %%
tau, p_value = stats.kendalltau(df1b['rate'], df1b['Latitude']) #sdorm and lat

# %%
print(tau, p_value) #dorm and lat
# Out:
# 0.2380619011845644 1.1786836156235738e-10

# %%
df1a.describe()
# Out:
#                   ID  germinated       total  non_germinated        rate  \
# count     370.000000  370.000000  370.000000      370.000000  370.000000
# mean    15959.164865   73.497297   81.078378        7.581081    0.892919
# std     28745.197954   26.992747   21.978601       12.168205    0.177758
# min        88.000000    2.000000   42.000000        0.000000    0.029412
# 25%      6201.250000   55.250000   65.000000        0.000000    0.867514
# 50%      9198.000000   73.000000   78.000000        4.000000    0.951020
# 75%      9838.750000   91.750000   93.000000        9.000000    1.000000
# max    116026.000000  146.000000  156.000000       82.000000    1.000000
#
#        Amplification_round_starting    Latitude   Longitude  \
# count                  3.700000e+02  370.000000  370.000000
# mean                   9.202100e+00   48.688514    3.514865
# std                    2.490267e-14    6.276391   18.873323
# min                    9.202100e+00   35.010000 -123.210000
# ...

# %%
#example of merging and subsetting
#merged_df = pd.merge(df, df1, on="Courses") # merge
#subset = titanic[["Age", "Sex"]] #subset

# %%
sdorm_ft = pd.read_csv("/Users/nhutran/Documents/PhD/dormancy_redo/runs/sdorm_ft_combined.csv")

# %%
sdorm_ft.describe()
# Out:
#                  ID  germinated       total  non_germinated        rate  \
# count    327.000000  327.000000  327.000000      326.000000  327.000000
# mean    7776.464832   17.752294   56.235474       38.588957    0.300692
# std     2323.259399   25.025443   14.559258       24.042841    0.369675
# min       88.000000    0.000000   36.000000        0.000000    0.000000
# 25%     6191.500000    0.000000   45.000000       18.250000    0.000000
# 50%     8256.000000    3.000000   52.000000       42.000000    0.066667
# 75%     9734.000000   31.000000   64.000000       54.000000    0.623611
# max    10017.000000   96.000000   96.000000       92.000000    1.000000
#
#        accession_longitude  accession_latitude        FT16  obs_unit_id  \
# count           327.000000          327.000000  327.000000   327.000000
# mean              3.856308           48.904876   79.367992  7073.406728
# std              19.956604            6.507063   25.324852   345.179516
# ...

# %%
sdorm_ft = sdorm_ft.rename(columns = {'accession_latitude':'Latitude'})

# %%
fig_sdorm = px.scatter(sdorm_ft, x='FT16',y='rate',color = 'Latitude', hover_name = "ID",
                 trendline = 'ols', template = "simple_white",
                color_continuous_scale = 'deep',
                labels={"FT16": "Flowering time (at 16 degree)",
                        "rate": "Secondary dormancy (germination rate)"}
                        )

# %%
fig_sdorm.show()
# Out:
# <div>                            <div id="ea05f69f-88d1-4b5f-9dba-bf0ba01ad110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea05f69f-88d1-4b5f-9dba-bf0ba01ad110")) {                    Plotly.newPlot(                        "ea05f69f-88d1-4b5f-9dba-bf0ba01ad110",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Flowering time (at 16 degree)=%{x}<br>Secondary dormancy (germination rate)=%{y}<br>Latitude=%{marker.color}<extra></extra>","hovertext":[8256.0,5865.0,9395.0,6924.0,6088.0,5023.0,9840.0,6034.0,9853.0,9866.0,1853.0,9931.0,9442.0,6090.0,9811.0,9819.0,6997.0,9839.0,9849.0,9850.0,9534.0,7717.0,1925.0,1954.0,1872.0,6074.0,9882.0,7523.0,7947.0,2276.0,9898.0,9756.0,6092.0,6098.0,6149.0,7356.0,6242.0,5353.0,5165.0,6413.0,9903
# ...

# %%
fig_sdorm.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_NEW_sdorm_ft16.html')

# %%
tau, p_value = stats.kendalltau(sdorm_ft['rate'], sdorm_ft['FT16']) #sdorm and ft16

# %%
print(tau, p_value)
# Out:
# -0.1282655473728976 0.0010667193198851301

# %%
######SLIDING WINDOW

# %%
#THIS IS ABOUT THE SLIDING WINDOW

# %%
os.chdir('/Users/nhutran/Documents/PhD/dormancy_redo/runs')

# %%
win16 = pd.read_csv("cor_sdorm_FT16_window.csv")
win10 = pd.read_csv("cor_sdorm_FT10_window.csv")

# %%
win16['r'] = round(win16['r'],2)

# %%
win16_signif = win16[win16['p']<=0.05]
win10_signif = win10[win10['p']<=0.05]

# %%
win16_signif.head()
# Out:
#           lat     r         p
# 63  48.620768 -0.25  0.029899
# 64  48.824834 -0.23  0.041214
# 80  49.687717 -0.23  0.040361
# 81  49.765180 -0.25  0.024846
# 82  49.904063 -0.24  0.033181

# %%
win16.loc[win16['p'] <= 0.05, ['group']] = '<0.05|=0.05'
win16.loc[win16['p'] > 0.05, ['group']] = '>0.05'

# %%
win10.loc[win10['p'] <= 0.05, ['group']] = '<0.05|=0.05'
win10.loc[win10['p'] > 0.05, ['group']] = '>0.05'

# %%
win16['group'] = win16['group'].astype(str) #convert to string

# %%
win10['group'] = win10['group'].astype(str)

# %%
win16.head()
# Out:
#          lat     r         p  group
# 0  47.992317 -0.08  0.490308  >0.05
# 1  47.967520 -0.06  0.589969  >0.05
# 2  47.654105 -0.07  0.540288  >0.05
# 3  47.618766 -0.04  0.707533  >0.05
# 4  47.733198 -0.07  0.537069  >0.05

# %%
fig1 = px.scatter(win16, x='lat',y='r',color = 'group',symbol = 'group',
                 trendline = 'ols', trendline_scope = 'overall',
                  template = "simple_white",
                color_discrete_sequence= ['rgb(93, 105, 177)','rgb(229, 134, 6)'],
                labels={"lat": "Mean latitude per window",
                        "r": "Correlation coefficient",
                       "group":"p-value"})

# %%
fig1.update_layout(font=dict(size=14))
# Out:
# <div>                            <div id="888d3f1f-c79e-4c17-ac2c-f85e8ce01534" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("888d3f1f-c79e-4c17-ac2c-f85e8ce01534")) {                    Plotly.newPlot(                        "888d3f1f-c79e-4c17-ac2c-f85e8ce01534",                        [{"hovertemplate":"p-value=>0.05<br>Mean latitude per window=%{x}<br>Correlation coefficient=%{y}<extra></extra>","legendgroup":">0.05","marker":{"color":"rgb(93, 105, 177)","symbol":"circle"},"mode":"markers","name":">0.05","orientation":"v","showlegend":true,"x":[47.9923170731707,47.9675195121951,47.6541048780488,47.6187658536585,47.7331975609756,47.3923048780488,47.1084024390244,47.1379146341463,46.7971829268293,46.7674268292683,47.1127195121951,47.052841463414
# ...

# %%
fig2 = px.scatter(win10, x='lat',y='r',color = 'group',symbol = 'group',
                 trendline = 'ols', trendline_scope = 'overall',
                  template = "simple_white",
                color_discrete_sequence= ['rgb(93, 105, 177)','rgb(229, 134, 6)'],
                labels={"lat": "Mean latitude per window",
                        "r": "Correlation coefficient",
                       "group":"p-value"})

# %%
fig2.update_layout(font=dict(size=14))
# Out:
# <div>                            <div id="012ed881-7005-40e6-aedd-3a12e5cf18b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("012ed881-7005-40e6-aedd-3a12e5cf18b8")) {                    Plotly.newPlot(                        "012ed881-7005-40e6-aedd-3a12e5cf18b8",                        [{"hovertemplate":"p-value=>0.05<br>Mean latitude per window=%{x}<br>Correlation coefficient=%{y}<extra></extra>","legendgroup":">0.05","marker":{"color":"rgb(93, 105, 177)","symbol":"circle"},"mode":"markers","name":">0.05","orientation":"v","showlegend":true,"x":[47.9923170731707,47.9675195121951,47.6541048780488,47.6187658536585,47.7331975609756,47.3923048780488,47.1084024390244,47.1379146341463,46.7971829268293,46.7674268292683,47.1127195121951,47.052841463414
# ...

# %%
#fig3 = px.scatter(win10_signif, x='lat',y='r',color = 'r',
#                 trendline = 'ols', template = "simple_white",
#                color_continuous_scale = 'Brwnyl',
#                labels={"lat": "Mean latitude per window",
#                        "r": "Correlation coefficient"})

# %%
fig1.write_html('/Users/nhutran/Documents/PhD/dormancy_redo/runs/fig_sdorm_FT16_slidewin.html')

# %%
tau, p_value = stats.kendalltau(win10['lat'], win10['r'])

# %%
print(tau, p_value)
# Out:
# -0.20713772346160422 1.6850636339483404e-07

# %%
figa = px.choropleth(df1, locations="Country",
                    color="bio9", # lifeExp is a column of gapminder
                    hover_name="Genotype", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
                    #animation_frame='year')
figb = px.scatter_geo(df1, locations="Country",
                    #size="lifeExp", # lifeExp is a column of gapminder
                    hover_name="Genotype", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
                    #animation_frame='year'
figa.add_trace(figb.data[0])
for i, frame in enumerate(figa.frames):
    figa.frames[i].data += (figb.frames[i].data[0],)

# %%
figa.show()
# Out:
# <div>                            <div id="a7eded4a-d151-4932-8b4a-99bef5437ba3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7eded4a-d151-4932-8b4a-99bef5437ba3")) {                    Plotly.newPlot(                        "a7eded4a-d151-4932-8b4a-99bef5437ba3",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{location}<br>bio9=%{z}<extra></extra>","hovertext":["Se-0","IP-Men-2","IP-Cmo-3","IP-Alo-0","IP-Deh-1","IP-Boa-0","IP-Coy-0","IP-Nog-17","IP-Ini-0","IP-Pie-0","IP-Pil-0","IP-Evs-0","IP-Vpa-1","IP-Lro-0","IP-Aul-0","IP-Ees-0","IP-Cir-0","IP-Gud-3","IP-Mun-0","IP-Usa-0","IP-Mac-0","IP-Vdt-0","IP-Pva-1","IP-Mie-1","IP-Smt-1","IP-Are-0","IP-Tam-0","IP-Dar-0","IP-Prd-0","IP-Som-
# ...
